# %%
# whenever raw data files have been altered, run "../scripts/xml_cleaner.py"

# %% [markdown]
# # Algorithm for extracting data from nested XML files (pre-cleaned)

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# custom function for extracting data from xml and saving to pandas DataFrame
def patent_xml2df(xml_data):
    root = ET.XML(xml_data)
    all_records = []
    for patent in root:
        record = {}
        for element in patent[0]:
            if element.tag == 'publication-reference':
                for item in element[0]:
                    if item.tag == 'date':
                        record['grant_date'] = item.text
                    elif item.tag == 'doc-number':
                        record['patent_number'] = item.text
            elif element.tag == 'application-reference':
                record['application_type'] = element.get('appl-type')
                for item in element[0]:
                    if item.tag == 'date':
                        record['filing_date'] = item.text
                    elif item.tag == 'doc-number':
                        record['application_number'] = item.text
            elif element.tag == 'figures':
                for item in element:
                    record[item.tag] = item.text
            elif element.tag == 'number-of-claims':
                record['number_of_claims'] = element.text
            elif element.tag == 'invention-title':
                if element.text == None:
                    record['invention_title'] = element[0].text + element[0].tail
                else:
                    record['invention_title'] = element.text
        all_records.append(record)
    return pd.DataFrame(all_records)

# %% [markdown]
# # Using globbing to get names of all cleaned XML file paths &
# # compiling list of DataFrames for concatenation

# %%
import glob

# use globbing to get all names of cleaned xml file paths
clean_files = glob.glob('../clean_data/*')


# loop over file names, extract data and concatenate into single DataFrame
xml_data_list = []
for clean_file in clean_files:
    data = open(clean_file).read()
    df = patent_xml2df(data)
    xml_data_list.append(df)
    
patents_df = pd.concat(xml_data_list, ignore_index=True)

# %% [markdown]
# # Casting Data Types for Specific Columns

# %%
# change the "filing_date" and "grant_date" columns to datetime objects
patents_df['filing_date'] = pd.to_datetime(patents_df['filing_date'])
patents_df['grant_date'] = pd.to_datetime(patents_df['grant_date'])

# change number-of-claims column to type int
patents_df['number_of_claims'] = patents_df['number_of_claims'].astype(int)

# %% [markdown]
# # Filling Null Values with 0
# ### (these values are omitted when value is zero)

# %%
patents_df['number-of-drawing-sheets'] = patents_df['number-of-drawing-sheets'].fillna('0')
patents_df['number-of-figures'] = patents_df['number-of-figures'].fillna('0')

# %% [markdown]
# # Displaying Resulting DataFrame

# %%
patents_df
# Out:
#        application_number application_type filing_date grant_date  \
# 0                29541102           design  2015-09-30 2017-10-31
# 1                29539276           design  2015-09-11 2017-10-31
# 2                29555649           design  2016-02-24 2017-10-31
# 3                29519436           design  2015-03-05 2017-10-31
# 4                35500692           design  2015-09-08 2017-10-31
# 5                29587571           design  2016-12-14 2017-10-31
# 6                29601989           design  2017-04-27 2017-10-31
# 7                29602056           design  2017-04-27 2017-10-31
# 8                29602061           design  2017-04-27 2017-10-31
# 9                29531309           design  2015-06-24 2017-10-31
# 10               29564782           design  2016-05-16 2017-10-31
# 11               29600261           design  2017-04-11 2017-10-31
# 12               29600325           design  2017-04-11 2017-10-31
# 13               29600327           design  2017-04-11 2017-10-31
# 14               29555322           design  2016-02-20 2017-10-31
# 15               29555379           design  2016-02-22 2017-10-31
# 16               29551984           design  2016-01-19 2017-10-31
# 17               29575399           design  2016-08-24 2017-10-31
# 18               29601958           design  2017-04-27 2017-10-31
# 19               29558536           design  2016-03-18 2017-10-31
# 20               35501221           design  2016-06-28 2017-10-31
# 21               29554119           design  2016-02-08 2017-10-31
# 22               29581027           design  2016-10-14 2017-10-31
# 23               29554123           design  2016-02-08 2017-10-31
# 24               29586583           design  2016-12-05 2017-10-31
# 25               29584229           design  2016-11-12 2017-10-31
# 26               29584675           design  2016-11-16 2017-10-31
# 27               29547197           design  2015-12-01 2017-10-31
# 28               29553874           design  2016-02-05 2017-10-31
# 29               29564820           design  2016-05-16 2017-10-31
# ...                   ...              ...         ...        ...
# 352537           14529661          utility  2014-10-31 2017-05-30
# 352538           15165325          utility  2016-05-26 2017-05-30
# 352539           14113817          utility  2011-04-27 2017-05-30
# 352540           14172706          utility  2014-02-04 2017-05-30
# 352541           14277900          utility  2014-05-15 2017-05-30
# 352542           14974284          utility  2015-12-18 2017-05-30
# 352543           15140335          utility  2016-04-27 2017-05-30
# 352544           15096333          utility  2016-04-12 2017-05-30
# 352545           14966304          utility  2015-12-11 2017-05-30
# 352546           14187747          utility  2014-02-24 2017-05-30
# 352547           14306496          utility  2014-06-17 2017-05-30
# 352548           14210171          utility  2014-03-13 2017-05-30
# 352549           14903013          utility  2014-07-02 2017-05-30
# 352550           13942858          utility  2013-07-16 2017-05-30
# 352551           14500136          utility  2014-09-29 2017-05-30
# 352552           15098948          utility  2016-04-14 2017-05-30
# 352553           14868511          utility  2015-09-29 2017-05-30
# 352554           14080729          utility  2013-11-14 2017-05-30
# 352555           14823414          utility  2015-08-11 2017-05-30
# 352556           15042277          utility  2016-02-12 2017-05-30
# 352557           14546670          utility  2014-11-18 2017-05-30
# 352558           13331331          utility  2011-12-20 2017-05-30
# 352559           14722371          utility  2015-05-27 2017-05-30
# 352560           14381640          utility  2012-03-01 2017-05-30
# 352561           14878688          utility  2015-10-08 2017-05-30
# 352562           15118815          utility  2014-12-16 2017-05-30
# 352563           14127986          utility  2012-06-21 2017-05-30
# 352564           14173577          utility  2014-02-05 2017-05-30
# 352565           14632279          utility  2015-02-26 2017-05-30
# 352566           15123179          utility  2014-03-05 2017-05-30
#
#                                           invention_title  \
# 0                                         Shaped tortilla
# 1                                            Utility belt
# 2                                               Brassiere
# 3                                                   Shirt
# 4                    Footmuff for a stroller for children
# 5                       Apparel with angled stretch panel
# 6                                                  Shorts
# 7                                                  Shorts
# 8                                                  Shorts
# 9                                                Leggings
# 10           Female and male apparel with detachable rear
# 11                                                  Pants
# 12                                                Garment
# 13                                                Garment
# 14                                       Hooded cape wrap
# 15                                       Hooded cape wrap
# 16      Marksmanship shirt with strap attachments for ...
# 17                                                   Vest
# 18                                                Garment
# 19                                                   Hood
# 20                                                 Sandal
# 21                                               Footwear
# 22                                                   Shoe
# 23                                               Footwear
# 24                                           Shoe midsole
# 25                                           Shoe outsole
# 26                                              Shoe sole
# 27                                              Shoe sole
# 28                                           Shoe outsole
# 29                                           Shoe outsole
# ...                                                   ...
# 352537                     Display device for an aircraft
# 352538               Lock structure of circuit board unit
# 352539  Housing unit for electrical components for use...
# 352540                         Wearable computing systems
# 352541  Collapsible enclosure cover for facilitating a...
# 352542  Collapsible enclosure cover for facilitating a...
# 352543                          Door of electronic device
# 352544  Systems and methods for securing panels to inf...
# 352545                            Cable management device
# 352546  Substrate support chuck cooling for deposition...
# 352547   Heat dissipating component and electronic device
# 352548    Atmospheric cooling of servers in a data center
# 352549  Electric converter with compact module arrange...
# 352550                                     Storage device
# 352551  Receptacle assembly with heat extraction from ...
# 352552  Heat spreader for a caged electrical connector...
# 352553                         Conformable thermal bridge
# 352554  Channel diversion device and related heat diss...
# 352555  Coolant distribution unit for a multi-node cha...
# 352556  System for mounting and cooling a computer com...
# 352557  Power conversion device and method for assembl...
# 352558  Controlling airflow within an explosion-proof ...
# 352559  Shield structure of electronic device unit and...
# 352560   Electronic unit with a PCB and two housing parts
# 352561  Electromagnetic interference suppressing struc...
# 352562  Electromagnetic shielding optical window based...
# 352563  Method for producing a housing enclosing at le...
# 352564  Substrate fixing apparatus and substrate worki...
# 352565  Component mounting method and component mounti...
# 352566  Component mounting line traceability informati...
#
#        number-of-drawing-sheets number-of-figures  number_of_claims  \
# 0                             3                 6                 1
# 1                             7                 9                 1
# 2                             7                 7                 1
# 3                             4                 4                 1
# 4                             7                 7                 1
# 5                             1                 1                 1
# 6                             5                 5                 1
# 7                             5                 5                 1
# 8                             6                 6                 1
# 9                             2                 3                 1
# 10                           18                18                 1
# 11                            5                 6                 1
# 12                            5                 9                 1
# 13                            5                 9                 1
# 14                            4                 7                 1
# 15                            4                 7                 1
# 16                            6                 6                 1
# 17                            2                 2                 1
# 18                            6                 6                 1
# 19                            5                 7                 1
# 20                            7                 7                 1
# 21                            6                 7                 1
# 22                            7                 7                 1
# 23                            6                 7                 1
# 24                            4                 4                 1
# 25                            4                 4                 1
# 26                            2                 2                 1
# 27                            5                 5                 1
# 28                            6                 6                 1
# 29                            5                 5                 1
# ...                         ...               ...               ...
# 352537                        4                 6                12
# 352538                       14                19                 4
# 352539                        2                 2                 9
# 352540                        8                12                 9
# 352541                        6                 7                 9
# 352542                        6                 7                 1
# 352543                        9                 9                20
# 352544                       13                15                19
# 352545                       13                13                18
# 352546                        3                 3                11
# 352547                       14                15                 5
# 352548                       12                13                20
# 352549                        3                 8                13
# 352550                       10                19                15
# 352551                        9                 9                20
# 352552                        4                 5                20
# 352553                        7                 9                20
# 352554                        6                 6                16
# 352555                        5                 5                15
# 352556                        9                 9                16
# 352557                       17                18                 3
# 352558                        5                 9                19
# 352559                        8                 9                15
# 352560                        3                 3                12
# 352561                        7                10                 8
# 352562                        7                15                10
# 352563                        3                20                23
# 352564                        6                13                18
# 352565                        7                11                 4
# 352566                        5                 6                 7
#
#        patent_number
# 0           D0800990
# 1           D0800991
# 2           D0800992
# 3           D0800993
# 4           D0800994
# 5           D0800995
# 6           D0800996
# 7           D0800997
# 8           D0800998
# 9           D0800999
# 10          D0801000
# 11          D0801001
# 12          D0801002
# 13          D0801003
# 14          D0801004
# 15          D0801005
# 16          D0801006
# 17          D0801007
# 18          D0801008
# 19          D0801009
# 20          D0801010
# 21          D0801011
# 22          D0801012
# 23          D0801013
# 24          D0801014
# 25          D0801015
# 26          D0801016
# 27          D0801017
# 28          D0801018
# 29          D0801019
# ...              ...
# 352537      09668364
# 352538      09668365
# 352539      09668366
# 352540      09668367
# 352541      09668368
# 352542      09668369
# 352543      09668370
# 352544      09668371
# 352545      09668372
# 352546      09668373
# 352547      09668374
# 352548      09668375
# 352549      09668376
# 352550      09668377
# 352551      09668378
# 352552      09668379
# 352553      09668380
# 352554      09668381
# 352555      09668382
# 352556      09668383
# 352557      09668384
# 352558      09668385
# 352559      09668387
# 352560      09668388
# 352561      09668390
# 352562      09668391
# 352563      09668392
# 352564      09668393
# 352565      09668394
# 352566      09668395
#
# [352567 rows x 9 columns]

# %% [markdown]
# # Conclusions regarding 'Null' values:
#
# There are 12633 patent grants that do not contain figures or drawings (and thus have no drawing sheets).
#
# The `invention_title` elements in the raw XML files often contained nested styling tags (e.g., the italics tag &lt;i&gt; was used for genus names of plants and other living organisms).

# %%
patents_df.to_csv('../intermediate_csv_files/clean_raw_data.csv')
